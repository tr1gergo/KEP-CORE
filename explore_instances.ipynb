# %% [markdown]
# # Kidney Exchange Instance Exploration
#
# First-pass inspection of the raw XML instances stored in `instances/`.

# %%
from pathlib import Path
import pandas as pd

from instance_analysis import load_instance, summarize_instances

INSTANCE_DIR = Path("instances_large")
instance_paths = sorted(INSTANCE_DIR.glob("*.xml"))
summaries = summarize_instances(instance_paths)

summary_df = pd.DataFrame(summaries).set_index("instance")
summary_df
# Out:
#               donors_total  donors_altruistic  donors_paired  \
# instance
# genxml-0.xml          1053                 53           1000
# genxml-1.xml          1053                 53           1000
# genxml-2.xml          1053                 53           1000
# genxml-3.xml          1053                 53           1000
# genxml-4.xml          1053                 53           1000
# genxml-5.xml          1053                 53           1000
# genxml-6.xml          1053                 53           1000
# genxml-7.xml          1053                 53           1000
# genxml-8.xml          1053                 53           1000
# genxml-9.xml          1053                 53           1000
#
#               donors_without_matches  recipients_total  matches_total  \
# instance
# genxml-0.xml                       0              1000         112958
# genxml-1.xml                       0              1000         100627
# genxml-2.xml                       0              1000         115231
# genxml-3.xml                       0              1000         100135
# genxml-4.xml                       0              1000         110058
# genxml-5.xml                       0              1000         111403
# genxml-6.xml                       0              1000         110105
# genxml-7.xml                       0              1000         120373
# genxml-8.xml                       0              1000         112866
# genxml-9.xml                       0              1000         115236
#
#               avg_matches_per_donor  avg_matches_altruistic  \
# instance
# genxml-0.xml             107.272555              102.339623
# genxml-1.xml              95.562203              100.301887
# genxml-2.xml             109.431149              104.358491
# genxml-3.xml              95.094967               97.433962
# genxml-4.xml             104.518519              112.566038
# genxml-5.xml             105.795821              121.622642
# genxml-6.xml             104.563153              121.962264
# genxml-7.xml             114.314340              117.283019
# genxml-8.xml             107.185185               99.264151
# genxml-9.xml             109.435897              119.924528
#
#               avg_matches_paired  avg_match_score  \
# instance
# genxml-0.xml             107.534        45.417775
# genxml-1.xml              95.311        45.639928
# genxml-2.xml             109.700        45.515512
# genxml-3.xml              94.971        45.579568
# genxml-4.xml             104.092        45.505979
# genxml-5.xml             104.957        45.447223
# genxml-6.xml             103.641        45.496027
# genxml-7.xml             114.157        45.477657
# genxml-8.xml             107.605        45.496509
# genxml-9.xml             108.880        45.577597
#
#                                  donor_bloodtype_counts  \
# instance
# genxml-0.xml  {'A': 451, 'O': 367, 'AB': 122, 'B': 113}
# genxml-1.xml  {'AB': 125, 'A': 448, 'B': 127, 'O': 353}
# genxml-2.xml  {'O': 375, 'A': 432, 'B': 114, 'AB': 132}
# genxml-3.xml  {'A': 447, 'O': 356, 'B': 117, 'AB': 133}
# genxml-4.xml  {'A': 449, 'O': 387, 'AB': 116, 'B': 101}
# genxml-5.xml  {'A': 423, 'O': 357, 'AB': 156, 'B': 117}
# genxml-6.xml  {'B': 113, 'AB': 136, 'O': 365, 'A': 439}
# genxml-7.xml  {'O': 403, 'AB': 101, 'A': 427, 'B': 122}
# genxml-8.xml   {'A': 422, 'O': 393, 'B': 142, 'AB': 96}
# genxml-9.xml  {'O': 393, 'A': 430, 'B': 114, 'AB': 116}
#
#                              recipient_bloodtype_counts  \
# instance
# genxml-0.xml  {'O': 420, 'A': 377, 'B': 102, 'AB': 101}
# genxml-1.xml    {'B': 93, 'A': 377, 'O': 443, 'AB': 87}
# genxml-2.xml   {'O': 423, 'A': 384, 'B': 101, 'AB': 92}
# genxml-3.xml   {'B': 110, 'O': 425, 'A': 377, 'AB': 88}
# genxml-4.xml   {'AB': 75, 'O': 449, 'A': 366, 'B': 110}
# genxml-5.xml   {'B': 106, 'A': 387, 'O': 422, 'AB': 85}
# genxml-6.xml   {'O': 459, 'B': 103, 'A': 351, 'AB': 87}
# genxml-7.xml   {'AB': 93, 'A': 359, 'B': 120, 'O': 428}
# genxml-8.xml   {'A': 382, 'O': 426, 'B': 105, 'AB': 87}
# genxml-9.xml   {'AB': 88, 'A': 401, 'O': 392, 'B': 119}
#
#                                            altruistic_donor_ids  \
# instance
# genxml-0.xml  [1191, 1192, 1193, 1194, 1195, 1196, 1197, 119...
# genxml-1.xml  [1199, 1200, 1201, 1202, 1203, 1204, 1205, 120...
# genxml-2.xml  [1230, 1231, 1232, 1233, 1234, 1235, 1236, 123...
# genxml-3.xml  [1200, 1201, 1202, 1203, 1204, 1205, 1206, 120...
# genxml-4.xml  [1215, 1216, 1217, 1218, 1219, 1220, 1221, 122...
# genxml-5.xml  [1171, 1172, 1173, 1174, 1175, 1176, 1177, 117...
# genxml-6.xml  [1198, 1199, 1200, 1201, 1202, 1203, 1204, 120...
# genxml-7.xml  [1217, 1218, 1219, 1220, 1221, 1222, 1223, 122...
# genxml-8.xml  [1205, 1206, 1207, 1208, 1209, 1210, 1211, 121...
# genxml-9.xml  [1186, 1187, 1188, 1189, 1190, 1191, 1192, 119...
#
#              donor_ids_without_matches
# instance
# genxml-0.xml                        []
# genxml-1.xml                        []
# genxml-2.xml                        []
# genxml-3.xml                        []
# genxml-4.xml                        []
# genxml-5.xml                        []
# genxml-6.xml                        []
# genxml-7.xml                        []
# genxml-8.xml                        []
# genxml-9.xml                        []

# %% [markdown]
# ## Aggregate Metrics
#
# High-level totals and averages across all instances.

# %%
counts = summary_df[[
    "donors_total",
    "donors_altruistic",
    "donors_paired",
    "recipients_total",
    "matches_total",
]].sum()
counts.to_frame(name="sum")
# Out:
#                        sum
# donors_total         10530
# donors_altruistic      530
# donors_paired        10000
# recipients_total     10000
# matches_total      1108992

# %%
averages = summary_df[[
    "avg_matches_per_donor",
    "avg_matches_altruistic",
    "avg_matches_paired",
    "avg_match_score",
]].mean()
averages.to_frame(name="mean")
# Out:
#                              mean
# avg_matches_per_donor   16.239241
# avg_matches_altruistic  18.825000
# avg_matches_paired      16.101333
# avg_match_score         46.108862

# %% [markdown]
# ## Donor-Level Details
#
# Look closer at the first instance to understand altruistic donors and match distributions.

# %%
example_instance = load_instance(instance_paths[0])

donors_df = pd.DataFrame([
    {
        "donor_id": donor.donor_id,
        "bloodtype": donor.bloodtype,
        "is_altruistic": donor.is_altruistic,
        "num_matches": donor.num_matches,
    }
    for donor in example_instance.donors
]).set_index("donor_id")
donors_df.head()
# Out:
#          bloodtype  is_altruistic  num_matches
# donor_id
# 0                A          False            9
# 1                O          False           32
# 2                A          False           14
# 3                A          False           12
# 4                A          False           12

# %%
donors_df[donors_df["is_altruistic"]].sort_values("num_matches", ascending=False)
# Out:
#          bloodtype  is_altruistic  num_matches
# donor_id
# 187              O           True           29
# 183              O           True           27
# 182              O           True           26
# 184              O           True           23
# 185              O           True           19
# 181              A           True           11
# 188              A           True           11
# 186             AB           True            2

# %%
donors_df.groupby("is_altruistic")["num_matches"].describe()
# Out:
#                count       mean       std  min   25%   50%    75%   max
# is_altruistic
# False          150.0  13.606667  9.335576  0.0   7.0  10.0  23.75  34.0
# True             8.0  18.500000  9.591663  2.0  11.0  21.0  26.25  29.0

# %%
recipients_df = pd.DataFrame([
    {
        "recipient_id": recipient.recipient_id,
        "bloodtype": recipient.bloodtype,
        "cPRA": recipient.c_pra,
        "has_blood_compatible_donor": recipient.has_blood_compatible_donor,
    }
    for recipient in example_instance.recipients
]).set_index("recipient_id")

recipients_df["has_blood_compatible_donor"].value_counts()
# Out:
# has_blood_compatible_donor
# True     82
# False    68
# Name: count, dtype: int64
